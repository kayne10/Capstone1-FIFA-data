# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %%
df = pd.read_csv('./data/teams.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 10 columns):
# Unnamed: 0             81 non-null int64
# Team                   81 non-null object
# Goals                  81 non-null float64
# Goals_Against          81 non-null float64
# Avg_Goals_Per_Match    81 non-null float64
# Cups_Hosted            81 non-null int64
# All_Wins               81 non-null int64
# All_Draws              81 non-null int64
# All_Losses             81 non-null int64
# Total_Matches          81 non-null int64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 6.4+ KB

# %%
df.head()
# Out:
#    Unnamed: 0        Team  Goals  Goals_Against  Avg_Goals_Per_Match  \
# 0           0      Turkey   20.0           17.0                  2.5
# 1           1      Norway    7.0            8.0                  1.0
# 2           2       Wales    4.0            4.0                  1.0
# 3           3  Costa Rica   18.0           24.0                  1.8
# 4           4         USA   38.0           64.0                  2.0
#
#    Cups_Hosted  All_Wins  All_Draws  All_Losses  Total_Matches
# 0            0         5          1           2              8
# 1            0         2          3           2              7
# 2            0         1          3           0              4
# 3            0         5          6          -1             10
# 4            1         8          6           5             19

# %%
matches = pd.read_csv('./data/CleanMatches.csv')

# %%
matches.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials',
#        'Winner'],
#       dtype='object')

# %%
matches['Year'].head()
# Out:
# 0    1930.0
# 1    1930.0
# 2    1930.0
# 3    1930.0
# 4    1930.0
# Name: Year, dtype: float64

# %%
new_df = matches.groupby('Year')

# %%
new_df.head()
# Out:
#      Unnamed: 0    Year              Datetime              Stage  \
# 0             0  1930.0  13 Jul 1930 - 15:00             Group 1
# 1             1  1930.0  13 Jul 1930 - 15:00             Group 4
# 2             2  1930.0  14 Jul 1930 - 12:45             Group 2
# 3             3  1930.0  14 Jul 1930 - 14:50             Group 3
# 4             4  1930.0  15 Jul 1930 - 16:00             Group 1
# 18           18  1934.0  27 May 1934 - 16:30   Preliminary round
# 19           19  1934.0  27 May 1934 - 16:30   Preliminary round
# 20           20  1934.0  27 May 1934 - 16:30   Preliminary round
# 21           21  1934.0  27 May 1934 - 16:30   Preliminary round
# 22           22  1934.0  27 May 1934 - 16:30   Preliminary round
# 35           35  1938.0  04 Jun 1938 - 17:00         First round
# 36           36  1938.0  05 Jun 1938 - 17:00         First round
# 37           37  1938.0  05 Jun 1938 - 17:00         First round
# ...

# %%
highest_goal_avg = df['Avg_Goals_Per_Match'].max()

# %%
df[df['Avg_Goals_Per_Match']==highest_goal_avg]
# Out:
#     Unnamed: 0    Team  Goals  Goals_Against  Avg_Goals_Per_Match  \
# 28          28  Brazil  225.0          114.0                 8.65
#
#     Cups_Hosted  All_Wins  All_Draws  All_Losses  Total_Matches
# 28            2        71         18         -63             26

# %%
df.corr()
# Out:
#                      Unnamed: 0     Goals  Goals_Against  Avg_Goals_Per_Match  \
# Unnamed: 0             1.000000  0.030602       0.065767             0.069942
# Goals                  0.030602  1.000000       0.891976             0.847224
# Goals_Against          0.065767  0.891976       1.000000             0.702171
# Avg_Goals_Per_Match    0.069942  0.847224       0.702171             1.000000
# Cups_Hosted           -0.028777  0.777443       0.777567             0.583617
# All_Wins               0.004335  0.988239       0.849023             0.826621
# All_Draws             -0.021494  0.852103       0.873543             0.648883
# All_Losses             0.045969 -0.894712      -0.648699            -0.786892
# Total_Matches          0.054499  0.812438       0.935778             0.592727
#
#                      Cups_Hosted  All_Wins  All_Draws  All_Losses  \
# Unnamed: 0             -0.028777  0.004335  -0.021494    0.045969
# ...

# %%
matches.set_index('Year')
# Out:
#         Unnamed: 0              Datetime                     Stage  \
# Year
# 1930.0           0  13 Jul 1930 - 15:00                    Group 1
# 1930.0           1  13 Jul 1930 - 15:00                    Group 4
# 1930.0           2  14 Jul 1930 - 12:45                    Group 2
# 1930.0           3  14 Jul 1930 - 14:50                    Group 3
# 1930.0           4  15 Jul 1930 - 16:00                    Group 1
# 1930.0           5  16 Jul 1930 - 14:45                    Group 1
# 1930.0           6  17 Jul 1930 - 12:45                    Group 2
# 1930.0           7  17 Jul 1930 - 14:45                    Group 4
# 1930.0           8  18 Jul 1930 - 14:30                    Group 3
# 1930.0           9  19 Jul 1930 - 12:50                    Group 1
# 1930.0          10  19 Jul 1930 - 15:00                    Group 1
# 1930.0          11  20 Jul 1930 - 13:00                    Group 2
# 1930.0          12  20 Jul 1930 - 15:00                    Group 4
# ...

# %%
matches.set_index(['Year','Winner'])
# Out:
#                        Unnamed: 0              Datetime  \
# Year   Winner
# 1930.0 France                   0  13 Jul 1930 - 15:00
#        USA                      1  13 Jul 1930 - 15:00
#        Yugoslavia               2  14 Jul 1930 - 12:45
#        Romania                  3  14 Jul 1930 - 14:50
#        Argentina                4  15 Jul 1930 - 16:00
#        Chile                    5  16 Jul 1930 - 14:45
#        Yugoslavia               6  17 Jul 1930 - 12:45
#        USA                      7  17 Jul 1930 - 14:45
#        Uruguay                  8  18 Jul 1930 - 14:30
#        Chile                    9  19 Jul 1930 - 12:50
#        Argentina               10  19 Jul 1930 - 15:00
#        Brazil                  11  20 Jul 1930 - 13:00
#        Paraguay                12  20 Jul 1930 - 15:00
#        Uruguay                 13  21 Jul 1930 - 14:50
#        Argentina               14  22 Jul 1930 - 14:45
#        Argentina               15  26 Jul 1930 - 14:45
# ...

# %%
matches.drop('Unnamed: 0',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-d3a1aa9c3ed6> in <module>()
# ----> 1 matches.drop('Unnamed: 0',axis=1,inplace=True)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3692                                            index=index, columns=columns,
#    3693                                            level=level, inplace=inplace,
# -> 3694                                            errors=errors)
#    3695
#    3696     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3106         for axis, labels in axes.items():
#    3107             if labels is not None:
# ...

# %%
df_06 = matches[matches['Year']==2006]

# %%
df_06
# Out:
#        Year              Datetime           Stage  \
# 644  2006.0  09 Jun 2006 - 18:00          Group A
# 645  2006.0  09 Jun 2006 - 21:00          Group A
# 646  2006.0  10 Jun 2006 - 15:00          Group B
# 647  2006.0  10 Jun 2006 - 18:00          Group B
# 648  2006.0  10 Jun 2006 - 21:00          Group C
# 649  2006.0  11 Jun 2006 - 15:00          Group C
# 650  2006.0  11 Jun 2006 - 18:00          Group D
# 651  2006.0  11 Jun 2006 - 21:00          Group D
# 652  2006.0  12 Jun 2006 - 15:00          Group F
# 653  2006.0  12 Jun 2006 - 18:00          Group E
# 654  2006.0  12 Jun 2006 - 21:00          Group E
# 655  2006.0  13 Jun 2006 - 15:00          Group G
# 656  2006.0  13 Jun 2006 - 18:00          Group G
# 657  2006.0  13 Jun 2006 - 21:00          Group F
# 658  2006.0  14 Jun 2006 - 15:00          Group H
# 659  2006.0  14 Jun 2006 - 18:00          Group H
# 660  2006.0  14 Jun 2006 - 21:00          Group A
# 661  2006.0  15 Jun 2006 - 15:00          Group A
# ...

# %%
matches.iloc[750:,:]
# Out:
#        Year              Datetime                     Stage  \
# 750  2010.0  24 Jun 2010 - 20:30                    Group E
# 751  2010.0  24 Jun 2010 - 20:30                    Group E
# 752  2010.0  25 Jun 2010 - 16:00                    Group G
# 753  2010.0  25 Jun 2010 - 16:00                    Group G
# 754  2010.0  25 Jun 2010 - 20:30                    Group H
# 755  2010.0  25 Jun 2010 - 20:30                    Group H
# 756  2010.0  26 Jun 2010 - 16:00                Round of 16
# 757  2010.0  26 Jun 2010 - 20:30                Round of 16
# 758  2010.0  27 Jun 2010 - 16:00                Round of 16
# 759  2010.0  27 Jun 2010 - 20:30                Round of 16
# 760  2010.0  28 Jun 2010 - 16:00                Round of 16
# 761  2010.0  28 Jun 2010 - 20:30                Round of 16
# 762  2010.0  29 Jun 2010 - 16:00                Round of 16
# 763  2010.0  29 Jun 2010 - 20:30                Round of 16
# 764  2010.0  02 Jul 2010 - 16:00             Quarter-finals
# ...

# %%
test_set = matches[matches['Year']==2014]
test_set
# Out:
#        Year              Datetime                     Stage  \
# 772  2014.0  12 Jun 2014 - 17:00                    Group A
# 773  2014.0  13 Jun 2014 - 13:00                    Group A
# 774  2014.0  13 Jun 2014 - 16:00                    Group B
# 775  2014.0  13 Jun 2014 - 18:00                    Group B
# 776  2014.0  14 Jun 2014 - 13:00                    Group C
# 777  2014.0  14 Jun 2014 - 16:00                    Group D
# 778  2014.0  14 Jun 2014 - 18:00                    Group D
# 779  2014.0  14 Jun 2014 - 22:00                    Group C
# 780  2014.0  15 Jun 2014 - 13:00                    Group E
# 781  2014.0  15 Jun 2014 - 16:00                    Group E
# 782  2014.0  15 Jun 2014 - 19:00                    Group F
# 783  2014.0  16 Jun 2014 - 13:00                    Group G
# 784  2014.0  16 Jun 2014 - 16:00                    Group F
# 785  2014.0  16 Jun 2014 - 19:00                    Group G
# 786  2014.0  17 Jun 2014 - 13:00                    Group H
# ...

# %%
train1 = matches[matches['Year']==2006]
train2 = matches[matches['Year']==2010]
# training_set = matches[(matches['Year']==2006) & (matches['Year']==2010)]
training_set = pd.concat([train1,train2])
training_set
# Out:
#        Year              Datetime                  Stage  \
# 644  2006.0  09 Jun 2006 - 18:00                 Group A
# 645  2006.0  09 Jun 2006 - 21:00                 Group A
# 646  2006.0  10 Jun 2006 - 15:00                 Group B
# 647  2006.0  10 Jun 2006 - 18:00                 Group B
# 648  2006.0  10 Jun 2006 - 21:00                 Group C
# 649  2006.0  11 Jun 2006 - 15:00                 Group C
# 650  2006.0  11 Jun 2006 - 18:00                 Group D
# 651  2006.0  11 Jun 2006 - 21:00                 Group D
# 652  2006.0  12 Jun 2006 - 15:00                 Group F
# 653  2006.0  12 Jun 2006 - 18:00                 Group E
# 654  2006.0  12 Jun 2006 - 21:00                 Group E
# 655  2006.0  13 Jun 2006 - 15:00                 Group G
# 656  2006.0  13 Jun 2006 - 18:00                 Group G
# 657  2006.0  13 Jun 2006 - 21:00                 Group F
# 658  2006.0  14 Jun 2006 - 15:00                 Group H
# ...

# %%
training_set.groupby('Year').agg({'Winner':'count'})
# Out:
#         Winner
# Year
# 2006.0      64
# 2010.0      64

# %%
training_set.to_csv('./data/2006-10_data.csv')

# %%
test_set.to_csv('./data/2014_data.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Team', 'Goals', 'Goals_Against', 'Avg_Goals_Per_Match',
#        'Cups_Hosted', 'All_Wins', 'All_Draws', 'All_Losses', 'Total_Matches'],
#       dtype='object')

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Team', 'Goals', 'Goals_Against', 'Avg_Goals_Per_Match', 'Cups_Hosted',
#        'All_Wins', 'All_Draws', 'All_Losses', 'Total_Matches'],
#       dtype='object')

# %%
cups = pd.read_csv('./data/WorldCups.csv')
cups[['Year','Winner']]
# Out:
#     Year      Winner
# 0   1930     Uruguay
# 1   1934       Italy
# 2   1938       Italy
# 3   1950     Uruguay
# 4   1954  Germany FR
# 5   1958      Brazil
# 6   1962      Brazil
# 7   1966     England
# 8   1970      Brazil
# 9   1974  Germany FR
# 10  1978   Argentina
# 11  1982       Italy
# 12  1986   Argentina
# 13  1990  Germany FR
# 14  1994      Brazil
# 15  1998      France
# 16  2002      Brazil
# 17  2006       Italy
# 18  2010       Spain
# 19  2014     Germany

# %%
champ = training_set[(training_set['Winner']=='Spain')]

# %%
champ.groupby('Year').agg({'Winner':'count'})
# Out:
#         Winner
# Year
# 2006.0       3
# 2010.0       6

# %%
champ2 = test_set[(test_set['Winner']=='Germany')]

# %%
champ2.groupby('Year').agg({'Winner':'count'})
# Out:
#         Winner
# Year
# 2014.0      10
